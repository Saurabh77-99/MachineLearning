# %% [markdown]
# <a href="https://colab.research.google.com/github/Saurabh77-99/MachineLearning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas Library:
#
# Useful for Data Processing and Analysis
#
# Pandas contains type - DataFrame:
# Pandas has mainly two object :- (1)DataFrame (2)Series
#
# It is two dimensional tabular data structure with labelled axes(rows and columns)
#
# Diabetes.csv

# %%
#importing pandas library
import pandas as pd
import numpy as np

# %% [markdown]
# Creating a Pandas DataFrame

# %%
# importing the boston house price data
from sklearn.datasets import fetch_openml
housing_dataset = fetch_openml(name="house_prices", as_frame=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %% [markdown]
# Bunch -> It is a dictionary object (key-value pairs) , it has a lot of data

# %%
type(housing_dataset)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(housing_dataset)
# Out:
# {'data':         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  None      Reg
# 1        2          20       RL         80.0     9600   Pave  None      Reg
# 2        3          60       RL         68.0    11250   Pave  None      IR1
# 3        4          70       RL         60.0     9550   Pave  None      IR1
# 4        5          60       RL         84.0    14260   Pave  None      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  None      Reg
# 1456  1457          20       RL         85.0    13175   Pave  None      Reg
# 1457  1458          70       RL         66.0     9042   Pave  None      Reg
# 1458  1459          20       RL         68.0     9717   Pave  None      Reg
# 1459  1460          20       RL         75.0     9937   Pave  None      Reg
#
# ...

# %%
# pandas Dataframe from dataset
housing_df = pd.DataFrame(housing_dataset.data,columns = housing_dataset.feature_names)
print(housing_df)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  None      Reg
# 1        2          20       RL         80.0     9600   Pave  None      Reg
# 2        3          60       RL         68.0    11250   Pave  None      IR1
# 3        4          70       RL         60.0     9550   Pave  None      IR1
# 4        5          60       RL         84.0    14260   Pave  None      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  None      Reg
# 1456  1457          20       RL         85.0    13175   Pave  None      Reg
# 1457  1458          70       RL         66.0     9042   Pave  None      Reg
# 1458  1459          20       RL         68.0     9717   Pave  None      Reg
# 1459  1460          20       RL         75.0     9937   Pave  None      Reg
#
# ...

# %%
housing_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  None      Reg
# 1   2          20       RL         80.0     9600   Pave  None      Reg
# 2   3          60       RL         68.0    11250   Pave  None      IR1
# 3   4          70       RL         60.0     9550   Pave  None      IR1
# 4   5          60       RL         84.0    14260   Pave  None      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0   None  None        None
# 1         Lvl    AllPub  ...           0        0   None  None        None
# 2         Lvl    AllPub  ...           0        0   None  None        None
# 3         Lvl    AllPub  ...           0        0   None  None        None
# 4         Lvl    AllPub  ...           0        0   None  None        None
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
housing_df.shape
# Out:
# (1460, 80)

# %%
type(housing_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Importing a Data from CSV file to a Pandas Dataframe

# %%
# csv file to pandas dataframe
diabetes_df = pd.read_csv("/content/diabetes.csv")

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# Loading the data from excel file to a pandas Dataframe
#
# pd.read_excel("filepath")

# %% [markdown]
# Exporting a Dataframe to a CSV File

# %%
# Exporting a Dataframe to a CSV File
housing_df.to_csv("housing.csv")

# %% [markdown]
# Exporting the Pandas Dataframe to an excel file:
#
# df.to_excel("filename")

# %%
#creating a dataframe with random values
random_df = pd.DataFrame(np.random.rand(20,10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.683416  0.163704  0.815342  0.575404  0.940855  0.655328  0.090347
# 1  0.660909  0.413905  0.745281  0.047114  0.397768  0.290155  0.417250
# 2  0.428254  0.638894  0.739141  0.802162  0.645475  0.830879  0.797439
# 3  0.939301  0.154258  0.432749  0.949790  0.432177  0.598385  0.414120
# 4  0.572706  0.732152  0.311869  0.135147  0.450349  0.230815  0.691030
#
#           7         8         9
# 0  0.949734  0.321689  0.442621
# 1  0.091829  0.825229  0.972567
# 2  0.117415  0.084109  0.715894
# 3  0.571848  0.684690  0.837258
# 4  0.636417  0.952366  0.489012

# %%
  random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# Inspecting a Dataframe

# %%
#finding number of rows and columns
housing_df.shape
# Out:
# (1460, 80)

# %%
# printing first five rows
housing_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  None      Reg
# 1   2          20       RL         80.0     9600   Pave  None      Reg
# 2   3          60       RL         68.0    11250   Pave  None      IR1
# 3   4          70       RL         60.0     9550   Pave  None      IR1
# 4   5          60       RL         84.0    14260   Pave  None      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0   None  None        None
# 1         Lvl    AllPub  ...           0        0   None  None        None
# 2         Lvl    AllPub  ...           0        0   None  None        None
# 3         Lvl    AllPub  ...           0        0   None  None        None
# 4         Lvl    AllPub  ...           0        0   None  None        None
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
# printing last five rows
housing_df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave  None      Reg
# 1456  1457          20       RL         85.0    13175   Pave  None      Reg
# 1457  1458          70       RL         66.0     9042   Pave  None      Reg
# 1458  1459          20       RL         68.0     9717   Pave  None      Reg
# 1459  1460          20       RL         75.0     9937   Pave  None      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 1455         Lvl    AllPub  ...           0        0   None   None
# 1456         Lvl    AllPub  ...           0        0   None  MnPrv
# 1457         Lvl    AllPub  ...           0        0   None  GdPrv
# 1458         Lvl    AllPub  ...           0        0   None   None
# 1459         Lvl    AllPub  ...           0        0   None   None
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#information about the dataframe
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# finding number of missing values
housing_df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# Length: 80, dtype: int64

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# counting values based on the labels
diabetes_df.value_counts("Outcome")
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# group values based on the mean
diabetes_df.groupby("Outcome").mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Statistical Measures

# %%
# count or number of values in each columns
diabetes_df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
# mean value columnwise
diabetes_df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
# standard deviation columnswise
diabetes_df.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
# minimum values
diabetes_df.min()
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
# maximum values
diabetes_df.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
# all statistical measures about the data
diabetes_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Manipulating a Dataframe

# %%
# adding a column to dataframe
housing_df['ADDED'] = housing_dataset.target

# %%
housing_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  None      Reg
# 1   2          20       RL         80.0     9600   Pave  None      Reg
# 2   3          60       RL         68.0    11250   Pave  None      IR1
# 3   4          70       RL         60.0     9550   Pave  None      IR1
# 4   5          60       RL         84.0    14260   Pave  None      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0   None  None        None       0      2
# 1         Lvl    AllPub  ...        0   None  None        None       0      5
# 2         Lvl    AllPub  ...        0   None  None        None       0      9
# 3         Lvl    AllPub  ...        0   None  None        None       0      2
# 4         Lvl    AllPub  ...        0   None  None        None       0     12
#
#   YrSold  SaleType  SaleCondition   ADDED
# ...

# %%
# removing a particular row
housing_df.drop(index=0,axis=0)
# Out:
#         Id MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour  \
# 1        2       RL         80.0     9600   Pave  None      Reg         Lvl
# 2        3       RL         68.0    11250   Pave  None      IR1         Lvl
# 3        4       RL         60.0     9550   Pave  None      IR1         Lvl
# 4        5       RL         84.0    14260   Pave  None      IR1         Lvl
# 5        6       RL         85.0    14115   Pave  None      IR1         Lvl
# ...    ...      ...          ...      ...    ...   ...      ...         ...
# 1455  1456       RL         62.0     7917   Pave  None      Reg         Lvl
# 1456  1457       RL         85.0    13175   Pave  None      Reg         Lvl
# 1457  1458       RL         66.0     9042   Pave  None      Reg         Lvl
# 1458  1459       RL         68.0     9717   Pave  None      Reg         Lvl
# 1459  1460       RL         75.0     9937   Pave  None      Reg         Lvl
#
# ...

# %%
# remove a column
housing_df.drop(columns="MSSubClass",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-6ab7e382b67a> in <cell line: 2>()
#       1 # remove a column
# ----> 2 housing_df.drop(columns="MSSubClass",axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# ...

# %%
# locating a row using index value
housing_df.iloc[2]
# Out:
# Id                    3
# MSZoning             RL
# LotFrontage        68.0
# LotArea           11250
# Street             Pave
#                   ...
# MoSold                9
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# ADDED            223500
# Name: 2, Length: 80, dtype: object

# %%
# locating a particular column
print(housing_df.iloc[:,0]) # prints first column of dataframe
print(housing_df.iloc[:,1])
print(housing_df.iloc[:,2])
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 1455    1456
# 1456    1457
# 1457    1458
# 1458    1459
# 1459    1460
# Name: Id, Length: 1460, dtype: int64
# 0       RL
# 1       RL
# 2       RL
# 3       RL
# 4       RL
#         ..
# 1455    RL
# 1456    RL
# 1457    RL
# 1458    RL
# 1459    RL
# Name: MSZoning, Length: 1460, dtype: object
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %% [markdown]
# Corelation
#
# (1) Positive Correlation
#
# (2) Negative Correlation

# %%
diabetes_df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...
